# %% [markdown]
# <a href="https://colab.research.google.com/github/anshulsawant/Void-Segmentation/blob/main/DistanceSegNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Important: Run this first!!!! ###
private_key = '''-----BEGIN OPENSSH PRIVATE KEY-----

-----END OPENSSH PRIVATE KEY-----
'''
# !mkdir -p /root/.ssh
with open("/root/.ssh/id_ed25519", "w+") as f:
  f.write(private_key)

# !ssh-keyscan -t ed25519 github.com > ~/.ssh/known_hosts
# Restrict the key permissions, or else SSH will complain.
# !chmod go-rwx /root/.ssh/id_ed25519
# !rm -rf /content/Void-Segmentation/
# !git clone git@github.com:anshulsawant/Void-Segmentation.git
import tensorflow as tf

from google.colab import drive

import cv2

from glob import glob
import numpy as np
import os

from tensorflow import keras
from keras import layers
from keras import backend as K
from IPython.display import clear_output
import matplotlib.pyplot as plt

from sklearn import metrics as skm
import random

from tensorflow.python.ops import math_ops

SIZE = 1024

import sys
if not '/content/Void-Segmentation/src' in sys.path:
  sys.path.append('/content/Void-Segmentation/src')
import importlib
importlib.invalidate_caches()
import images
import datasets
import utils
import metrics as M
import models
import losses
importlib.reload(images)
importlib.reload(datasets)
importlib.reload(utils)
importlib.reload(M)
importlib.reload(models)
importlib.reload(losses)
# Out:
# # github.com:22 SSH-2.0-babeld-831dd33d
# Cloning into 'Void-Segmentation'...
# Warning: Permanently added the ED25519 host key for IP address '140.82.121.4' to the list of known hosts.
# remote: Enumerating objects: 14235, done.
# remote: Counting objects: 100% (353/353), done.
# remote: Compressing objects: 100% (170/170), done.
# remote: Total 14235 (delta 205), reused 314 (delta 182), pack-reused 13882
# Receiving objects: 100% (14235/14235), 579.25 MiB | 19.72 MiB/s, done.
# Resolving deltas: 100% (5721/5721), done.
# Checking out files: 100% (5096/5096), done.
# <module 'losses' from '/content/Void-Segmentation/src/losses.py'>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
u, v, _, _ = images.load_image_paths()
print(images.ROOT)
print(len(u))
## Can you spot the problem in the masks below?
i = 781 ## random.randint(0, len(u))
print(i)
print(u[i])
x = images.load_image(u[i])
y = images.load_mask(v[i])
print(x.shape)
print(y.shape)

raw_image = cv2.imread(u[i])
raw_mask = cv2.imread(v[i], flags=cv2.IMREAD_GRAYSCALE)
plt.rcParams["figure.figsize"] = (10,20)
plt.figure()
f, axarr = plt.subplots(1, 2)
axarr[0].imshow(x[:,:,0], cmap = 'gray') 
axarr[1].imshow(y[:,:,0], cmap = 'gray')
plt.show()
# Out:
# Loading images from /content/Void-Segmentation/dataset/train.
# /content/Void-Segmentation
# 864
# 781
# /content/Void-Segmentation/dataset/train/images/100kX_300kV_0651_3_3_rot180.png
# (512, 512, 1)
# (512, 512, 1)

# %% [markdown]
# **Image Augmentation Methods**

# %%
    # Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
model = models.distance_model(SIZE//2)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512)]   0           []
#
#  reshape (Reshape)              (None, 512, 512, 1)  0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 512, 512, 4)  104         ['reshape[0][0]']
#
#  concatenate (Concatenate)      (None, 512, 512, 5)  0           ['reshape[0][0]',
#                                                                   'conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 4)  504         ['concatenate[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 512, 512, 9)  0           ['reshape[0][0]',
#                                                                   'conv2d[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 9)  0           ['concatenate_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 16  3616        ['max_pooling2d[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 16  10016       ['concatenate_2[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 41  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 41  0          ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 32  32832       ['max_pooling2d_1[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 128, 128, 73  0           ['max_pooling2d_1[0][0]',
#                                 )                                 'conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 32  58432       ['concatenate_4[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 10  0           ['max_pooling2d_1[0][0]',
#                                 5)                                'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 105)  0          ['concatenate_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 64)   168064      ['max_pooling2d_2[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 169)  0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   270464      ['concatenate_6[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 64, 64, 233)  0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_6[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 128, 128, 32  29856      ['concatenate_7[0][0]']
#  ose)                           )
#
#  concatenate_8 (Concatenate)    (None, 128, 128, 13  0           ['max_pooling2d_1[0][0]',
#                                 7)                                'conv2d_4[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_transpose[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 32  109632      ['concatenate_8[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 128, 128, 16  0           ['concatenate_8[0][0]',
#                                 9)                                'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 32  135232      ['concatenate_9[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 128, 128, 20  0           ['concatenate_8[0][0]',
#                                 1)                                'conv2d_8[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 256, 256, 16  12880      ['concatenate_10[0][0]']
#  spose)                         )
#
#  concatenate_11 (Concatenate)   (None, 256, 256, 57  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_2[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_transpose_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 256, 256, 16  22816       ['concatenate_11[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 256, 256, 73  0           ['concatenate_11[0][0]',
#                                 )                                 'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 256, 256, 16  29216       ['concatenate_12[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 256, 256, 89  0           ['concatenate_11[0][0]',
#                                 )                                 'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 512, 512, 8)  2856       ['concatenate_13[0][0]']
#  spose)
#
#  concatenate_14 (Concatenate)   (None, 512, 512, 17  0           ['reshape[0][0]',
#                                 )                                 'conv2d[0][0]',
#                                                                   'conv2d_1[0][0]',
#                                                                   'conv2d_transpose_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 512, 512, 4)  616         ['concatenate_14[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 512, 512, 13  0           ['reshape[0][0]',
#                                 )                                 'conv2d[0][0]',
#                                                                   'conv2d_1[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 512, 512, 2)  1276        ['concatenate_15[0][0]']
#
#  lambda (Lambda)                (None, 512, 512)     0           ['conv2d_13[0][0]']
#
#  flatten (Flatten)              (None, 262144)       0           ['lambda[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 524288)       0           ['flatten[0][0]',
#                                                                   'flatten[0][0]']
#
# ==================================================================================================
# Total params: 888,412
# Trainable params: 888,412
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def distance_loss(y_true, y_pred):
    s = tf.cast(y_true.shape[1]/2, tf.int32)
    y_true_mask = y_true[:,0:s]
    y_true_dist = y_true[:,s:2*s] + 1
    bce = K.binary_crossentropy(y_true_mask, y_pred[:,0:s])
    return K.mean(y_true_dist*bce)
opt = tf.keras.optimizers.Adam(learning_rate=0.001)

def schedule(epoch, lr):
  return lr*np.exp(-0.1)

callbacks = [
    keras.callbacks.ModelCheckpoint("/content/drive/MyDrive/Segmentation/segmentation_distance_50", save_best_only=True),
    keras.callbacks.LearningRateScheduler(schedule)
]
# Train the model, doing validation at the end of each epoch.
epochs = 50
training_data, validation_data = datasets.create_distance_dataset(batch=32)
keras.backend.clear_session()

restore = False
retrain = False
if restore:
  model = tf.keras.models.load_model('/content/drive/MyDrive/Segmentation/segmentation_distance_50', custom_objects = {'distance_loss':distance_loss})
  if retrain:
    keras.backend.set_value(model.optimizer.learning_rate, 0.0001)
    model.fit(training_data, validation_data=validation_data, epochs=epochs, callbacks = callbacks)
else:
  model.compile(tf.keras.optimizers.Adam(learning_rate=0.001), loss=distance_loss)
  model.fit(training_data, validation_data=validation_data, epochs=epochs, callbacks = callbacks)
# Out:
# Loading images from /content/Void-Segmentation/dataset/train.
# Creating dataset with 864 images.
# Using 691 images for training.
# Epoch 1/50
# 22/22 [==============================] - ETA: 0s - loss: 0.5737INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 36s 2s/step - loss: 0.5737 - val_loss: 0.5536 - lr: 9.0484e-04
# Epoch 2/50
# 22/22 [==============================] - ETA: 0s - loss: 0.4960INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.4960 - val_loss: 0.4081 - lr: 8.1873e-04
# Epoch 3/50
# 22/22 [==============================] - ETA: 0s - loss: 0.3806INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 34s 2s/step - loss: 0.3806 - val_loss: 0.3528 - lr: 7.4082e-04
# Epoch 4/50
# 22/22 [==============================] - ETA: 0s - loss: 0.3202INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 34s 2s/step - loss: 0.3202 - val_loss: 0.2899 - lr: 6.7032e-04
# Epoch 5/50
# 22/22 [==============================] - ETA: 0s - loss: 0.2898INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.2898 - val_loss: 0.2778 - lr: 6.0653e-04
# Epoch 6/50
# 22/22 [==============================] - ETA: 0s - loss: 0.2425INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.2425 - val_loss: 0.2350 - lr: 5.4881e-04
# Epoch 7/50
# 22/22 [==============================] - ETA: 0s - loss: 0.2095INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 45s 2s/step - loss: 0.2095 - val_loss: 0.2145 - lr: 4.9659e-04
# Epoch 8/50
# 22/22 [==============================] - ETA: 0s - loss: 0.1954INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.1954 - val_loss: 0.1799 - lr: 4.4933e-04
# Epoch 9/50
# 22/22 [==============================] - ETA: 0s - loss: 0.1806INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.1806 - val_loss: 0.1632 - lr: 4.0657e-04
# Epoch 10/50
# 22/22 [==============================] - ETA: 0s - loss: 0.1718INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.1718 - val_loss: 0.1552 - lr: 3.6788e-04
# Epoch 11/50
# 22/22 [==============================] - 31s 1s/step - loss: 0.1687 - val_loss: 0.1602 - lr: 3.3287e-04
# Epoch 12/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1531 - val_loss: 0.1595 - lr: 3.0119e-04
# Epoch 13/50
# 22/22 [==============================] - ETA: 0s - loss: 0.1591INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.1591 - val_loss: 0.1406 - lr: 2.7253e-04
# Epoch 14/50
# 22/22 [==============================] - 31s 1s/step - loss: 0.1449 - val_loss: 0.1469 - lr: 2.4660e-04
# Epoch 15/50
# 22/22 [==============================] - ETA: 0s - loss: 0.1415INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.1415 - val_loss: 0.1285 - lr: 2.2313e-04
# Epoch 16/50
# 22/22 [==============================] - 31s 1s/step - loss: 0.1407 - val_loss: 0.1392 - lr: 2.0190e-04
# Epoch 17/50
# 22/22 [==============================] - 31s 1s/step - loss: 0.1333 - val_loss: 0.1418 - lr: 1.8268e-04
# Epoch 18/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1351 - val_loss: 0.1518 - lr: 1.6530e-04
# Epoch 19/50
# 22/22 [==============================] - 31s 1s/step - loss: 0.1329 - val_loss: 0.1369 - lr: 1.4957e-04
# Epoch 20/50
# 22/22 [==============================] - ETA: 0s - loss: 0.1322INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.1322 - val_loss: 0.1258 - lr: 1.3534e-04
# Epoch 21/50
# 22/22 [==============================] - ETA: 0s - loss: 0.1282INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.1282 - val_loss: 0.1219 - lr: 1.2246e-04
# Epoch 22/50
# 22/22 [==============================] - 31s 1s/step - loss: 0.1251 - val_loss: 0.1269 - lr: 1.1080e-04
# Epoch 23/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1271 - val_loss: 0.1231 - lr: 1.0026e-04
# Epoch 24/50
# 22/22 [==============================] - ETA: 0s - loss: 0.1248INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.1248 - val_loss: 0.1137 - lr: 9.0718e-05
# Epoch 25/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1246 - val_loss: 0.1231 - lr: 8.2085e-05
# Epoch 26/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1213 - val_loss: 0.1283 - lr: 7.4274e-05
# Epoch 27/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1181 - val_loss: 0.1154 - lr: 6.7206e-05
# Epoch 28/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1187 - val_loss: 0.1165 - lr: 6.0810e-05
# Epoch 29/50
# 22/22 [==============================] - ETA: 0s - loss: 0.1168INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.1168 - val_loss: 0.1110 - lr: 5.5023e-05
# Epoch 30/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1152 - val_loss: 0.1117 - lr: 4.9787e-05
# Epoch 31/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1155 - val_loss: 0.1125 - lr: 4.5049e-05
# Epoch 32/50
# 22/22 [==============================] - 31s 1s/step - loss: 0.1160 - val_loss: 0.1175 - lr: 4.0762e-05
# Epoch 33/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1175 - val_loss: 0.1114 - lr: 3.6883e-05
# Epoch 34/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1142 - val_loss: 0.1289 - lr: 3.3373e-05
# Epoch 35/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1160 - val_loss: 0.1141 - lr: 3.0197e-05
# Epoch 36/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1179 - val_loss: 0.1195 - lr: 2.7324e-05
# Epoch 37/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1121 - val_loss: 0.1207 - lr: 2.4724e-05
# Epoch 38/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1147 - val_loss: 0.1157 - lr: 2.2371e-05
# Epoch 39/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1140 - val_loss: 0.1118 - lr: 2.0242e-05
# Epoch 40/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1129 - val_loss: 0.1202 - lr: 1.8316e-05
# Epoch 41/50
# 22/22 [==============================] - ETA: 0s - loss: 0.1161INFO:tensorflow:Assets written to: /content/drive/MyDrive/Segmentation/segmentation_distance_50/assets
# 22/22 [==============================] - 35s 2s/step - loss: 0.1161 - val_loss: 0.1030 - lr: 1.6573e-05
# Epoch 42/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1117 - val_loss: 0.1126 - lr: 1.4996e-05
# Epoch 43/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1152 - val_loss: 0.1214 - lr: 1.3569e-05
# Epoch 44/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1150 - val_loss: 0.1120 - lr: 1.2277e-05
# Epoch 45/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1130 - val_loss: 0.1171 - lr: 1.1109e-05
# Epoch 46/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1129 - val_loss: 0.1071 - lr: 1.0052e-05
# Epoch 47/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1117 - val_loss: 0.1186 - lr: 9.0953e-06
# Epoch 48/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1119 - val_loss: 0.1165 - lr: 8.2297e-06
# Epoch 49/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1112 - val_loss: 0.1128 - lr: 7.4466e-06
# Epoch 50/50
# 22/22 [==============================] - 32s 1s/step - loss: 0.1109 - val_loss: 0.1224 - lr: 6.7379e-06

# %%
ds = datasets.create_distance_test_dataset(batch=31)

eval = model.evaluate(x = ds, return_dict=True)
print(eval)
# Out:
# Loading images from /content/Void-Segmentation/dataset/test.
# Loading 28 images for testing.
# 1/1 [==============================] - 1s 503ms/step - loss: 0.1131
# {'loss': 0.11307384073734283}

# %%
ds = datasets.create_distance_test_dataset(batch=31)

def top(x):
  s = tf.cast(x.shape[0]/2, tf.int32)
  return x[0:s]
def top_np(x):
  s = int(x.shape[0]/2)
  return x[0:s]

def top_all(x):
  s = tf.cast(x.shape[1]/2, tf.int32)
  return x[:,0:s]

def accuracy_ordering(images, masks, predictions):
  acc = [None]*images.shape[0]
  for i in range(images.shape[0]):
    prediction = top(predictions[i])
    prediction = prediction.reshape((512, 512))
    image = images[i].reshape((512, 512))
    mask = top(masks[i])
    mask = mask.reshape((512, 512))      
    p = (prediction >= 0.5)*1 
    mislabels = np.abs(mask - p)
    n = np.sum(mislabels == 1.)
    acc[i] = 1 - n/(512. * 512.)
  return np.array(acc).argsort()

def plot_predictions(images, masks, predictions):
  images = images.numpy()
  masks = masks.numpy()
  acc_order = accuracy_ordering(images, masks, predictions)
  images = images[acc_order]
  masks = masks[acc_order]
  predictions = predictions[acc_order]
  N = images.shape[0]
  n_cols = 4
  n_rows = N
  plt.rcParams["figure.figsize"] = (5*n_cols, 5*n_rows)
  f, a = plt.subplots(n_rows, n_cols)
  plt.axis('off')
  for i in range(N):
    plot_prediction(images[i], masks[i], top_np(predictions[i]), a[i])

def plot_prediction(image, mask, prediction, ax):
  prediction = prediction.reshape((512, 512))
  image = image.reshape((512, 512))
  mask = top(mask).reshape((512, 512))
  p = (prediction >= 0.5)*1
  ax[0].axis('off')
  ax[0].imshow(image, cmap='gray')
  ax[1].imshow(p, cmap='gray')
  ax[2].imshow(mask, cmap='gray')
  white = np.ones((512, 512))
  mislabels = np.abs(mask - p)
  ax[3].imshow(image, cmap='gray', alpha=( 1 - mislabels))
  n = np.sum(mislabels == 1.)
  acc = 1 - n/(512. * 512.)
  ax[0].title.set_text(str(np.round(acc, 4)))

for (x, y) in ds:
  yy = model.predict(x)
  plot_predictions(x, y, yy)
# Out:
# Loading images from /content/Void-Segmentation/dataset/test.
# Loading 28 images for testing.

# %%
def top_all(x):
  s = tf.cast(x.shape[1]/2, tf.int32)
  return x[:,0:s]

ds = datasets.create_distance_test_dataset(batch = 29)
images = None
masks = None
for image, mask in ds:
  images = image
  masks = top_all(mask)

masks_pred = top_all(model.predict(images))
print(masks_pred.shape)

# %%
M.all_feature_metrics(masks, masks_pred, thresholds = [0.5, 0.6, 0.7, 0.8, 0.9])

# %%
x = M.all_pixel_metrics(masks, masks_pred, np.arange(0.01, 0.98, 0.01))
print(x)
